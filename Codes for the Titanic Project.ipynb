# %%
        #MY FIRST PROJECT
###standard imports 
import pandas as pd
import yfinance as yf
import numpy as np
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
from pandas import DataFrame as df, Series

from unicodedata import normalize

from numpy.random import randn
import sys ### this is used to be able to see output directly without having to safe


from bs4 import BeautifulSoup as soup
from pandas import read_html ## this is necessary to be able to read html files 
import pandas_datareader as pdr ###importing python data reader
from pandas_datareader import data
import requests

import json

## statistic import 
from scipy import stats

##plotting imports
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

####website to check seaborn plots ###
###http://seaborn.pydata.org/tutorial/categorical.html

# %%
titanic = pd.read_excel('titanic3.xls')

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
## QUESTION 1::: who were the pessangers on Titanic###
##first grouping them by sex
gender = titanic.groupby('sex')

# %%
gender.describe()
# Out:
#        pclass                                              survived            \
#         count      mean       std  min  25%  50%  75%  max    count      mean
# sex
# female  466.0  2.154506  0.866181  1.0  1.0  2.0  3.0  3.0    466.0  0.727468
# male    843.0  2.372479  0.811908  1.0  2.0  3.0  3.0  3.0    843.0  0.190985
#
#         ...       fare             body                                     \
#         ...        75%       max  count       mean         std  min    25%
# sex     ...
# female  ...  55.331275  512.3292    8.0  166.62500  138.110657  7.0  52.75
# male    ...  26.550000  512.3292  113.0  160.39823   95.035289  1.0  79.00
#
#
#           50%    75%    max
# sex
# female  133.5  306.0  328.0
# male    155.0  255.0  322.0
#
# [2 rows x 56 columns]

# %%
##there more males than female on the titanic ship 
#percentages 
sns.distplot(titanic['age'], bins=70)
# Out:
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
titanic['age'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
titanic['age'].mean()
# Out:
# 29.8811345124283

# %%
titanic.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
    #### Using factor plot ####

sns.countplot('sex',data=titanic)
# Out:
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
titanic['pclass'].value_counts()
titanic['pclass']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1304    3
# 1305    3
# 1306    3
# 1307    3
# 1308    3
# Name: pclass, Length: 1309, dtype: int64

# %%
sns.countplot('pclass',data=titanic, hue='sex')
# Out:
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %%
    ####creating a function##
def agegrouping(passenger):
        age,sex = passenger
        if age <=10:
            return 'child'
        elif age>10 and age<20:
            return 'tenager'
        elif age >20 and age<40:
            return 'adult'
        else:
            return 'aged'

titanic['agegroup'] = titanic[['age','sex']].apply(agegrouping, axis = 1)

# %%
titanic.head(50)
# Out:
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 1        1         1                     Allison, Master. Hudson Trevor
# 2        1         0                       Allison, Miss. Helen Loraine
# 3        1         0               Allison, Mr. Hudson Joshua Creighton
# 4        1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1         1                                Anderson, Mr. Harry
# 6        1         1                  Andrews, Miss. Kornelia Theodosia
# 7        1         0                             Andrews, Mr. Thomas Jr
# 8        1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1         0                            Artagaveytia, Mr. Ramon
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12       1         1                      Aubart, Mme. Leontine Pauline
# 13       1         1                       Barber, Miss. Ellen "Nellie"
# 14       1         1               Barkworth, Mr. Algernon Henry Wilson
# 15       1         0                                Baumann, Mr. John D
# 16       1         0                           Baxter, Mr. Quigg Edmond
# 17       1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18       1         1                              Bazzani, Miss. Albina
# 19       1         0                               Beattie, Mr. Thomson
# 20       1         1                      Beckwith, Mr. Richard Leonard
# 21       1         1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 22       1         1                              Behr, Mr. Karl Howell
# 23       1         1                              Bidois, Miss. Rosalie
# 24       1         1                                  Bird, Miss. Ellen
# 25       1         0                                Birnbaum, Mr. Jakob
# 26       1         1                            Bishop, Mr. Dickinson H
# 27       1         1            Bishop, Mrs. Dickinson H (Helen Walton)
# 28       1         1                             Bissette, Miss. Amelia
# 29       1         1          Bjornstrom-Steffansson, Mr. Mauritz Hakan
# 30       1         0                       Blackwell, Mr. Stephen Weart
# 31       1         1                                   Blank, Mr. Henry
# 32       1         1                            Bonnell, Miss. Caroline
# 33       1         1                           Bonnell, Miss. Elizabeth
# 34       1         0                           Borebank, Mr. John James
# 35       1         1                           Bowen, Miss. Grace Scott
# 36       1         1                        Bowerman, Miss. Elsie Edith
# 37       1         1      Bradley, Mr. George ("George Arthur Brayton")
# 38       1         0                            Brady, Mr. John Bertram
# 39       1         0                                 Brandeis, Mr. Emil
# 40       1         0                          Brewe, Dr. Arthur Jackson
# 41       1         1          Brown, Mrs. James Joseph (Margaret Tobin)
# 42       1         1     Brown, Mrs. John Murray (Caroline Lane Lamson)
# 43       1         1    Bucknell, Mrs. William Robert (Emma Eliza Ward)
# 44       1         1                    Burns, Miss. Elizabeth Margaret
# 45       1         0                  Butt, Major. Archibald Willingham
# 46       1         0                              Cairns, Mr. Alexander
# 47       1         1                  Calderhead, Mr. Edward Pennington
# 48       1         1   Candee, Mrs. Edward (Helen Churchill Hungerford)
# 49       1         1                 Cardeza, Mr. Thomas Drake Martinez
#
#        sex      age  sibsp  parch    ticket      fare        cabin embarked  \
# 0   female  29.0000      0      0     24160  211.3375           B5        S
# 1     male   0.9167      1      2    113781  151.5500      C22 C26        S
# 2   female   2.0000      1      2    113781  151.5500      C22 C26        S
# 3     male  30.0000      1      2    113781  151.5500      C22 C26        S
# 4   female  25.0000      1      2    113781  151.5500      C22 C26        S
# 5     male  48.0000      0      0     19952   26.5500          E12        S
# 6   female  63.0000      1      0     13502   77.9583           D7        S
# 7     male  39.0000      0      0    112050    0.0000          A36        S
# 8   female  53.0000      2      0     11769   51.4792         C101        S
# 9     male  71.0000      0      0  PC 17609   49.5042          NaN        C
# 10    male  47.0000      1      0  PC 17757  227.5250      C62 C64        C
# 11  female  18.0000      1      0  PC 17757  227.5250      C62 C64        C
# 12  female  24.0000      0      0  PC 17477   69.3000          B35        C
# 13  female  26.0000      0      0     19877   78.8500          NaN        S
# 14    male  80.0000      0      0     27042   30.0000          A23        S
# 15    male      NaN      0      0  PC 17318   25.9250          NaN        S
# 16    male  24.0000      0      1  PC 17558  247.5208      B58 B60        C
# 17  female  50.0000      0      1  PC 17558  247.5208      B58 B60        C
# 18  female  32.0000      0      0     11813   76.2917          D15        C
# 19    male  36.0000      0      0     13050   75.2417           C6        C
# 20    male  37.0000      1      1     11751   52.5542          D35        S
# 21  female  47.0000      1      1     11751   52.5542          D35        S
# 22    male  26.0000      0      0    111369   30.0000         C148        C
# 23  female  42.0000      0      0  PC 17757  227.5250          NaN        C
# 24  female  29.0000      0      0  PC 17483  221.7792          C97        S
# 25    male  25.0000      0      0     13905   26.0000          NaN        C
# 26    male  25.0000      1      0     11967   91.0792          B49        C
# 27  female  19.0000      1      0     11967   91.0792          B49        C
# 28  female  35.0000      0      0  PC 17760  135.6333          C99        S
# 29    male  28.0000      0      0    110564   26.5500          C52        S
# 30    male  45.0000      0      0    113784   35.5000            T        S
# 31    male  40.0000      0      0    112277   31.0000          A31        C
# 32  female  30.0000      0      0     36928  164.8667           C7        S
# 33  female  58.0000      0      0    113783   26.5500         C103        S
# 34    male  42.0000      0      0    110489   26.5500          D22        S
# 35  female  45.0000      0      0  PC 17608  262.3750          NaN        C
# 36  female  22.0000      0      1    113505   55.0000          E33        S
# 37    male      NaN      0      0    111427   26.5500          NaN        S
# 38    male  41.0000      0      0    113054   30.5000          A21        S
# 39    male  48.0000      0      0  PC 17591   50.4958          B10        C
# 40    male      NaN      0      0    112379   39.6000          NaN        C
# 41  female  44.0000      0      0  PC 17610   27.7208           B4        C
# 42  female  59.0000      2      0     11769   51.4792         C101        S
# 43  female  60.0000      0      0     11813   76.2917          D15        C
# 44  female  41.0000      0      0     16966  134.5000          E40        C
# 45    male  45.0000      0      0    113050   26.5500          B38        S
# 46    male      NaN      0      0    113798   31.0000          NaN        S
# 47    male  42.0000      0      0  PC 17476   26.2875          E24        S
# 48  female  53.0000      0      0  PC 17606   27.4458          NaN        C
# 49    male  36.0000      0      1  PC 17755  512.3292  B51 B53 B55        C
#
#    boat   body                                       home.dest agegroup
# 0     2    NaN                                    St Louis, MO    adult
# 1    11    NaN                 Montreal, PQ / Chesterville, ON    child
# 2   NaN    NaN                 Montreal, PQ / Chesterville, ON    child
# 3   NaN  135.0                 Montreal, PQ / Chesterville, ON    adult
# 4   NaN    NaN                 Montreal, PQ / Chesterville, ON    adult
# 5     3    NaN                                    New York, NY     aged
# 6    10    NaN                                      Hudson, NY     aged
# 7   NaN    NaN                                     Belfast, NI    adult
# 8     D    NaN                             Bayside, Queens, NY     aged
# 9   NaN   22.0                             Montevideo, Uruguay     aged
# 10  NaN  124.0                                    New York, NY     aged
# 11    4    NaN                                    New York, NY  tenager
# 12    9    NaN                                   Paris, France    adult
# 13    6    NaN                                             NaN    adult
# 14    B    NaN                                   Hessle, Yorks     aged
# 15  NaN    NaN                                    New York, NY     aged
# 16  NaN    NaN                                    Montreal, PQ    adult
# 17    6    NaN                                    Montreal, PQ     aged
# 18    8    NaN                                             NaN    adult
# 19    A    NaN                                    Winnipeg, MN    adult
# 20    5    NaN                                    New York, NY    adult
# 21    5    NaN                                    New York, NY     aged
# 22    5    NaN                                    New York, NY    adult
# 23    4    NaN                                             NaN     aged
# 24    8    NaN                                             NaN    adult
# 25  NaN  148.0                               San Francisco, CA    adult
# 26    7    NaN                                    Dowagiac, MI    adult
# 27    7    NaN                                    Dowagiac, MI  tenager
# 28    8    NaN                                             NaN    adult
# 29    D    NaN              Stockholm, Sweden / Washington, DC    adult
# 30  NaN    NaN                                     Trenton, NJ     aged
# 31    7    NaN                                  Glen Ridge, NJ     aged
# 32    8    NaN                                  Youngstown, OH    adult
# 33    8    NaN               Birkdale, England Cleveland, Ohio     aged
# 34  NaN    NaN                           London / Winnipeg, MB     aged
# 35    4    NaN                                 Cooperstown, NY     aged
# 36    6    NaN                St Leonards-on-Sea, England Ohio    adult
# 37    9    NaN                                 Los Angeles, CA     aged
# 38  NaN    NaN                                     Pomeroy, WA     aged
# 39  NaN  208.0                                       Omaha, NE     aged
# 40  NaN    NaN                                Philadelphia, PA     aged
# 41    6    NaN                                      Denver, CO     aged
# 42    D    NaN                                     Belmont, MA     aged
# 43    8    NaN                                Philadelphia, PA     aged
# 44    3    NaN                                             NaN     aged
# 45  NaN    NaN                                  Washington, DC     aged
# 46  NaN    NaN                                             NaN     aged
# 47    5    NaN                                    New York, NY     aged
# 48    6    NaN                                  Washington, DC     aged
# 49    3    NaN  Austria-Hungary / Germantown, Philadelphia, PA    adult

# %%
sns.countplot('pclass', data=titanic, hue="agegroup")
# Out:
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %%
titanic['agegroup'].value_counts()
# Out:
# adult      553
# aged       531
# tenager    139
# child       86
# Name: agegroup, dtype: int64

# %%
    ##Drawing multiple plots together##
##set an object 
fig = sns.FacetGrid(titanic, hue='sex', aspect =4) ##FacetGrid allows multiple plots. the will use the age column
fig.map(sns.kdeplot, 'age', shade=True)

oldest = titanic['age'].max()

fig.set(xlim=(0, oldest))

fig.add_legend()

# %%
    ##Drawing multiple plots together##
##set an object 
fig = sns.FacetGrid(titanic, hue='agegroup', aspect =4) ##FacetGrid allows multiple plots. the will use the age column
fig.map(sns.kdeplot, 'age', shade=True)

oldest = titanic['age'].max()

fig.set(xlim=(0, oldest))

fig.add_legend()

# %%
    ##Drawing multiple plots together##
##set an object 
fig = sns.FacetGrid(titanic, hue='pclass', aspect =4) ##FacetGrid allows multiple plots. the will use the age column
fig.map(sns.kdeplot, 'age', shade=True)

oldest = titanic['age'].max()

fig.set(xlim=(0, oldest))

fig.add_legend()

# %%
##We can see that the 1st class had a normal distribution but the 2nd and third class are  right skewed toward towards the mean

# %%
##What deck were the persengers on and how does that relate to their class
##Note the the deck is represented as the cabin and there are null values which we'll have to drop
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542      NaN        C  NaN
# 1305  female      NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.5000      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.0000      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.0000      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
deck = titanic['cabin'].dropna() ### we created an object deck
deck
# Out:
# 0            B5
# 1       C22 C26
# 2       C22 C26
# 3       C22 C26
# 4       C22 C26
#          ...
# 1189         G6
# 1217      F G73
# 1230         G6
# 1231         G6
# 1249        F38
# Name: cabin, Length: 295, dtype: object

# %%
levels =[] ####here we just created an empty list called levels

for level in deck:   ### deck is the object we created ealier.. so for every item in the object
    levels.append(level[0]) ## now we use this to append only the first element of all the cabin list, i.e which are either A,B,or C that precedes the cabin number.
    
cabin_df = df(levels)
#levels
cabin_df.columns = ['cabin']

sns.countplot('cabin', data=cabin_df, palette='winter_d')
# Out:
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cabin', ylabel='count'>

# %%
##droping the T cabin 
cabin_df = cabin_df[cabin_df.cabin!='T']

# %%
sns.countplot('cabin', data=cabin_df, palette='autumn_d')
# Out:
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cabin', ylabel='count'>

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest agegroup
# 0                     St Louis, MO    adult
# 1  Montreal, PQ / Chesterville, ON    child
# 2  Montreal, PQ / Chesterville, ON    child
# 3  Montreal, PQ / Chesterville, ON    adult
# 4  Montreal, PQ / Chesterville, ON    adult

# %%
##Question 3: where did the passengers come from by age-group?
sns.countplot('embarked', data=titanic, hue='agegroup')
# Out:
# <AxesSubplot:xlabel='embarked', ylabel='count'>

# %%
##Question 3: where did the passengers come from by age-group?
sns.countplot('embarked', data=titanic, hue='pclass', order=['C','Q','S'])  ####the order attribute arranges the bbarplot in order specified
# Out:
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='embarked', ylabel='count'>

# %%
##Who is alone and who is with family?

def with_fam(not_alone):
    parch,sibsp=not_alone
    if parch > 0 or sibsp > 0 :
        return 'has family'
    else:
        return 'alone'
titanic['travelled_with'] = titanic[['parch', 'sibsp']].apply(with_fam, axis=1)

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542      NaN        C  NaN
# 1305  female      NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.5000      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.0000      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.0000      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest agegroup travelled_with  \
# 0       NaN                     St Louis, MO    adult          alone
# 1       NaN  Montreal, PQ / Chesterville, ON    child     has family
# 2       NaN  Montreal, PQ / Chesterville, ON    child     has family
# 3     135.0  Montreal, PQ / Chesterville, ON    adult     has family
# 4       NaN  Montreal, PQ / Chesterville, ON    adult     has family
# ...     ...                              ...      ...            ...
# 1304  328.0                              NaN  tenager     has family
# 1305    NaN                              NaN     aged     has family
# 1306  304.0                              NaN    adult          alone
# 1307    NaN                              NaN    adult          alone
# 1308    NaN                              NaN    adult          alone
#
#             alone
# 0           Alone
# 1     with family
# 2     with family
# 3     with family
# 4     with family
# ...           ...
# 1304  with family
# 1305  with family
# 1306        Alone
# 1307        Alone
# 1308        Alone
#
# [1309 rows x 17 columns]

# %%
sns.countplot('pclass', data=titanic, hue='travelled_with' )
# Out:
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %%
titanic['travelled_with'].value_counts()
# Out:
# alone         790
# has family    519
# Name: travelled_with, dtype: int64

# %%
##ANother way is to add both colums together ##
titanic['alone'] = titanic['sibsp']+titanic['parch']

# %%
titanic['alone'].loc[titanic['alone']>0] = 'with family'
titanic['alone'].loc[titanic['alone']==0] = 'Alone'
# Out:
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
titanic.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest agegroup  \
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN  tenager
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN     aged
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN    adult
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN    adult
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN    adult
#
#      travelled_with        alone
# 1304     has family  with family
# 1305     has family  with family
# 1306          alone        Alone
# 1307          alone        Alone
# 1308          alone        Alone

# %%
sns.countplot('pclass', data=titanic, hue='alone', palette='Blues')
# Out:
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %%
titanic['alone'].value_counts()
# Out:
# Alone          790
# with family    519
# Name: alone, dtype: int64

# %%
sns.countplot('alone', data=titanic, palette='Blues')
# Out:
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='alone', ylabel='count'>

# %%
##What factors helped someone survived the sinking or crash of the titanic##
##making a column called survivor###
titanic['survivor'] = titanic.survived.map({0:'no', 1:'yes'}) ##this creates another column gives it the value of no if the value in survived is 0 and yes if 1

sns.countplot('survivor', data=titanic)
# Out:
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='survivor', ylabel='count'>

# %%
sns.countplot('pclass', data=titanic, hue='survivor')
# Out:
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %%
sns.factorplot('pclass', 'survived', data=titanic)
# Out:
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
##condidering class and gender ##
sns.factorplot('pclass','survived', data=titanic, hue='agegroup')
##the graph shows that being a chilkd increases the chances of survival which is higher in the second class compaered to the 1st class and becuase there are fewer children in class 1 and 3, the highest chances of survival as child occur in the second class
##also the chances of survivor decreases with increase in age
# Out:
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot('pclass','survived', data=titanic, hue='sex')
##checking whether sex has an effect on survivor indicates that being a male in any of the class really reduces the chances of survival.
# Out:
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
##Using a linear plot on age and survival##
sns.lmplot('age', 'survived', data= titanic)
# Out:
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot('age', 'survived',hue='pclass', data= titanic, palette='winter')
##the curve indicates that there is more deaths in the third class and  and the chances of survival decrease as we go from 1st to the 3rd class###
# Out:
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
##cleaning up the figure a little bit more to not have all the ageas in a single plot##
###making age bins###

generations = [10, 20, 40,60,70]

sns.lmplot('age', 'survived', hue='pclass', data= titanic, x_bins=generations)

##The data showed that the chances of survival for a child with the range of 10 year is higher in second class than in first class and the teil end the chances of survival is the same for the age group of 70 for both second and third class##
##the standard deviation is shown by the distance of the points from the individual lines the yello round dot from thr yelow line is the standard deviation for each group
# Out:
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
##checking the survival by sex ##
sns.lmplot('age', 'survived', data=titanic, hue='sex', palette='winter', x_bins=generations)

##if you are an older female, it is more likely for you to survive than for an older male.
##note the the standard deviation is the distance of the. points from the line

# %%
## Did the deck have an effect on the passenger survival rate ? did this answer match up with my intuition 
##Did having a family member increase the odds of surving the crash 
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542      NaN        C  NaN
# 1305  female      NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.5000      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.0000      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.0000      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest agegroup travelled_with  \
# 0       NaN                     St Louis, MO    adult          alone
# 1       NaN  Montreal, PQ / Chesterville, ON    child     has family
# 2       NaN  Montreal, PQ / Chesterville, ON    child     has family
# 3     135.0  Montreal, PQ / Chesterville, ON    adult     has family
# 4       NaN  Montreal, PQ / Chesterville, ON    adult     has family
# ...     ...                              ...      ...            ...
# 1304  328.0                              NaN  tenager     has family
# 1305    NaN                              NaN     aged     has family
# 1306  304.0                              NaN    adult          alone
# 1307    NaN                              NaN    adult          alone
# 1308    NaN                              NaN    adult          alone
#
#             alone survivor
# 0           Alone      yes
# 1     with family      yes
# 2     with family       no
# 3     with family       no
# 4     with family       no
# ...           ...      ...
# 1304  with family       no
# 1305  with family       no
# 1306        Alone       no
# 1307        Alone       no
# 1308        Alone       no
#
# [1309 rows x 18 columns]

# %%
#effect of deck on survival
## creating a new dataframe with a new column of deck class
titanic2 = titanic.dropna(subset= ['cabin']) ##subset is used to drop na of a particular column#
titanic2
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1189       3         1                  Sandstrom, Miss. Marguerite Rut
# 1217       3         0       Soholt, Mr. Peter Andreas Lauritz Andersen
# 1230       3         0                       Strom, Miss. Telma Matilda
# 1231       3         0       Strom, Mrs. Wilhelm (Elna Matilda Persson)
# 1249       3         0                                 Tobin, Mr. Roger
#
#          sex      age  sibsp  parch   ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0    24160  211.3375       B5        S    2
# 1       male   0.9167      1      2   113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2   113781  151.5500  C22 C26        S  NaN
# 3       male  30.0000      1      2   113781  151.5500  C22 C26        S  NaN
# 4     female  25.0000      1      2   113781  151.5500  C22 C26        S  NaN
# ...      ...      ...    ...    ...      ...       ...      ...      ...  ...
# 1189  female   4.0000      1      1  PP 9549   16.7000       G6        S   13
# 1217    male  19.0000      0      0   348124    7.6500    F G73        S  NaN
# 1230  female   2.0000      0      1   347054   10.4625       G6        S  NaN
# 1231  female  29.0000      1      1   347054   10.4625       G6        S  NaN
# 1249    male      NaN      0      0   383121    7.7500      F38        Q  NaN
#
#        body                        home.dest agegroup travelled_with  \
# 0       NaN                     St Louis, MO    adult          alone
# 1       NaN  Montreal, PQ / Chesterville, ON    child     has family
# 2       NaN  Montreal, PQ / Chesterville, ON    child     has family
# 3     135.0  Montreal, PQ / Chesterville, ON    adult     has family
# 4       NaN  Montreal, PQ / Chesterville, ON    adult     has family
# ...     ...                              ...      ...            ...
# 1189    NaN                              NaN    child     has family
# 1217    NaN                              NaN  tenager          alone
# 1230    NaN                              NaN    child     has family
# 1231    NaN                              NaN    adult     has family
# 1249    NaN                              NaN     aged          alone
#
#             alone survivor
# 0           Alone      yes
# 1     with family      yes
# 2     with family       no
# 3     with family       no
# 4     with family       no
# ...           ...      ...
# 1189  with family      yes
# 1217        Alone       no
# 1230  with family       no
# 1231  with family       no
# 1249        Alone       no
#
# [295 rows x 18 columns]

# %%
titanic2
deck_in = titanic2['cabin']


deck = []

for i in deck_in:
    i = i[0]
    deck.append(i)
    
    
df(deck)##make deck a dataframe
# Out:
#      0
# 0    B
# 1    C
# 2    C
# 3    C
# 4    C
# ..  ..
# 290  G
# 291  F
# 292  G
# 293  G
# 294  F
#
# [295 rows x 1 columns]

# %%
##adding decks as a column to titanic 2 data
                    ##titanic_2 = pd.concat([titanic2, deck2],axis=1)#### doesn't work returned more rows

                        ##renaming the column.
                        #titanic_2['cabin'].describe()####

                #titanic_2
titanic2['deck']= deck
titanic2
# Out:
# <ipython-input-534-8efac51b36a1>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic2['deck']= deck
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1189       3         1                  Sandstrom, Miss. Marguerite Rut
# 1217       3         0       Soholt, Mr. Peter Andreas Lauritz Andersen
# 1230       3         0                       Strom, Miss. Telma Matilda
# 1231       3         0       Strom, Mrs. Wilhelm (Elna Matilda Persson)
# 1249       3         0                                 Tobin, Mr. Roger
#
#          sex      age  sibsp  parch   ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0    24160  211.3375       B5        S    2
# 1       male   0.9167      1      2   113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2   113781  151.5500  C22 C26        S  NaN
# 3       male  30.0000      1      2   113781  151.5500  C22 C26        S  NaN
# 4     female  25.0000      1      2   113781  151.5500  C22 C26        S  NaN
# ...      ...      ...    ...    ...      ...       ...      ...      ...  ...
# 1189  female   4.0000      1      1  PP 9549   16.7000       G6        S   13
# 1217    male  19.0000      0      0   348124    7.6500    F G73        S  NaN
# 1230  female   2.0000      0      1   347054   10.4625       G6        S  NaN
# 1231  female  29.0000      1      1   347054   10.4625       G6        S  NaN
# 1249    male      NaN      0      0   383121    7.7500      F38        Q  NaN
#
#        body                        home.dest agegroup travelled_with  \
# 0       NaN                     St Louis, MO    adult          alone
# 1       NaN  Montreal, PQ / Chesterville, ON    child     has family
# 2       NaN  Montreal, PQ / Chesterville, ON    child     has family
# 3     135.0  Montreal, PQ / Chesterville, ON    adult     has family
# 4       NaN  Montreal, PQ / Chesterville, ON    adult     has family
# ...     ...                              ...      ...            ...
# 1189    NaN                              NaN    child     has family
# 1217    NaN                              NaN  tenager          alone
# 1230    NaN                              NaN    child     has family
# 1231    NaN                              NaN    adult     has family
# 1249    NaN                              NaN     aged          alone
#
#             alone survivor deck
# 0           Alone      yes    B
# 1     with family      yes    C
# 2     with family       no    C
# 3     with family       no    C
# 4     with family       no    C
# ...           ...      ...  ...
# 1189  with family      yes    G
# 1217        Alone       no    F
# 1230  with family       no    G
# 1231  with family       no    G
# 1249        Alone       no    F
#
# [295 rows x 19 columns]

# %%
titanic2['deck'].value_counts()
# Out:
# C    94
# B    65
# D    46
# E    41
# A    22
# F    21
# G     5
# T     1
# Name: deck, dtype: int64

# %%
sns.factorplot('deck','survived', data= titanic2, hue='deck', order=['A','B','C','D','E','F','G','T'])

## the graph doesnt really show a particular partern as to whether the deck really affects the chances of survival.
##quite surpriseing because one would have thought that the lower decks would have had the greater chance of getting out of the ship faster to safety than those on the upper deck, but then on a second thought it is intuitive to see that most people would have 
##definitely clustered together at the deck that is less flooded and safe at the time which removed the importance of deck as everyon would have lkeaped out to safety.
# Out:
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot('deck','survived', data= titanic2, order=['A','B','C','D','E','F','G','T'])
# Out:
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
##Did having a family member increase the odds of surving the crash

# %%
sns.factorplot('travelled_with', 'survived',data= titanic2, hue='agegroup')
##This is quite interesting as it showed that the chances of survival doubles when a passenger has a family than someone who is alone except for adults whihc indicates no changes at all whether or not one is alone.
# Out:
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/mayorbaba/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
